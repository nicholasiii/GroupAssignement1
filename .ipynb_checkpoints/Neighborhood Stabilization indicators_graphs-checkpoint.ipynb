# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
df = pd.read_csv('indicators.csv')
df.head()
# Out:
#                  Unnamed: 0  pop_est_2017  pop_census_2010  pov_est_2017  \
# 0          Bellaire-Puritas         14458            13365            25
# 1   Broadway-Slavic Village         19730            22432            43
# 2           Brooklyn Centre          9081             8954            37
# 3     Buckeye-Shaker Square         12351            12470            30
# 4          Buckeye-Woodhill          7445             6657            54
#
#    pov_census_2010  viol_10  viol_11  viol_12  viol_13  viol_14  ...  \
# 0               21      116       91       91       81      102  ...
# 1               35      463      410      490      501      381  ...
# 2               29      133      158      150      171      179  ...
# 3               29      132      154      163      168      141  ...
# 4               51      138      114      152      150      153  ...
#
#    land_bank_num_16  land_bank_num_17  vacant_num_10  vacant_num_11  \
# ...

# %%
# Filter the DataFrame down only to those columns to chart
lb_parcels = df[['Neighborhood','land_bank_num_10','land_bank_num_13','land_bank_num_17']]

# Set the index to be 'Neighborhood'
lb_parcels = lb_parcels.set_index('Neighborhood')

lb_parcels.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-66bbeaa307fe> in <module>
#       1 # Filter the DataFrame down only to those columns to chart
# ----> 2 lb_parcels = df[['Neighborhood','land_bank_num_10','land_bank_num_13','land_bank_num_17']]
#       3
#       4 # Set the index to be 'Neighborhood'
#       5 lb_parcels = lb_parcels.set_index('Neighborhood')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
# ...

# %%
# Create a bar chart of the data
lb_parcels.plot(kind="barh", figsize=(5,8))
#lb_parcels.set_xticklabels(df['Neighborhood'], rotation=45)

plt.title('Land Bank Parcels')
plt.tight_layout()

plt.savefig('LandBankParcels.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
vacant = df[['Neighborhood','vacant_num_10','vacant_num_13','vacant_num_17']]

# Set the index to 'Neighborhood'
vacant = vacant.set_index('Neighborhood')

vacant.head()
# Out:
#                           vacant_num_10  vacant_num_13  vacant_num_17
# Neighborhood
#  Bellaire-Puritas                   284            284            260
#  Broadway-Slavic Village            905            832            654
#  Brooklyn Centre                    102            120            102
#  Buckeye-Shaker Square              102            120            103
#  Buckeye-Woodhill                   385            322            177

# %%
# Create a bar chart of the data
vacant.plot(kind="barh", figsize=(5,8))

plt.title('Vacant Parcels')
plt.tight_layout()

plt.savefig('VacantParcels.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
forcl = df[['Neighborhood','forcl_10','forcl_13','forcl_17']]

# Set the index to 'Neighborhood'
forcl = forcl.set_index('Neighborhood')

forcl.head()
# Out:
#                           forcl_10  forcl_13  forcl_17
# Neighborhood
#  Bellaire-Puritas            177.0     137.0      74.0
#  Broadway-Slavic Village     348.0     250.0     256.0
#  Brooklyn Centre              67.0      70.0      50.0
#  Buckeye-Shaker Square       118.0     105.0      75.0
#  Buckeye-Woodhill             55.0      54.0      60.0

# %%
# Create a bar chart of the data
forcl.plot(kind="barh", figsize=(5,8))

plt.title('Foreclosures')
plt.tight_layout()

plt.savefig('Foreclosures.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
median_price = df[['Neighborhood','homes_med_price_10','homes_med_price_13','homes_med_price_17']]

# Set the index to 'Neighborhood'
median_price = median_price.set_index('Neighborhood')

median_price.head()
# Out:
#                           homes_med_price_10  homes_med_price_13  \
# Neighborhood
#  Bellaire-Puritas                    30050.0             27600.0
#  Broadway-Slavic Village             11000.0             13350.0
#  Brooklyn Centre                     20000.0             17750.0
#  Buckeye-Shaker Square               14250.0             19500.0
#  Buckeye-Woodhill                    14350.0             22650.0
#
#                           homes_med_price_17
# Neighborhood
#  Bellaire-Puritas                    40950.0
#  Broadway-Slavic Village             19900.0
#  Brooklyn Centre                     26250.0
#  Buckeye-Shaker Square               30000.0
#  Buckeye-Woodhill                    24300.0

# %%
# Create a bar chart of the data
median_price.plot(kind="barh", figsize=(5,8))

plt.title('Median Home Price')
plt.tight_layout()

plt.savefig('MedianPrice.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
median_value = df[['Neighborhood','homes_med_val_10','homes_med_val_13','homes_med_val_17']]

# Set the index to 'Neighborhood'
median_value = median_value.set_index('Neighborhood')

median_value.head()
# Out:
#                           homes_med_val_10  homes_med_val_13  homes_med_val_17
# Neighborhood
#  Bellaire-Puritas                  65650.0           55100.0           50700.0
#  Broadway-Slavic Village           40400.0           26700.0           28000.0
#  Brooklyn Centre                   51500.0           44850.0           42300.0
#  Buckeye-Shaker Square             65900.0           51700.0           45850.0
#  Buckeye-Woodhill                  32500.0           24950.0           23600.0

# %%
# Create a bar chart of the data
median_value.plot(kind="barh", figsize=(5,8))

plt.title('Median Home Value')
plt.tight_layout()

plt.savefig('MedianValue.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">
