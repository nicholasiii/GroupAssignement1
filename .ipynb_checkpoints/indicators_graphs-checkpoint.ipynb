# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
df = pd.read_csv('indicators.csv')
df.head(10)
# Out:
#                Neighborhood  land_bank_num_10  land_bank_num_11  \
# 0   Broadway-Slavic Village               585               791
# 1     Collinwood-Nottingham               392               471
# 2                 Glenville               963              1178
# 3            Mount Pleasant               278               341
# 4               Union-Miles               650               752
# 5           Brooklyn Centre                45                47
# 6      Goodrich-Kirtland Pk                54                54
# 7                 Jefferson                20                22
# 8                 Ohio City                85                97
# 9                   Tremont               108               111
#
#    land_bank_num_12  land_bank_num_13  land_bank_num_14  land_bank_num_15  \
# 0               926              1052              1173              1348
# 1               540               615               665               748
# 2              1328              1457              1563              1752
# 3               402               478               552               676
# 4               858               923               979              1086
# 5                54                53                63                72
# 6                57                60                61                63
# 7                27                35                43                55
# 8               108               102               106               115
# 9               120               119               124               132
#
#    land_bank_num_16  land_bank_num_17  vacant_num_17  ...  homes_num_11  \
# 0              1599              1723            654  ...          5169
# 1               818               844            250  ...          2335
# 2              1928              2006            686  ...          5762
# 3               787               867            275  ...          3419
# 4              1225              1253            362  ...          5709
# 5                81                83            102  ...          1536
# 6                67                73            110  ...           332
# 7                54                54            149  ...          5690
# 8               113               104            291  ...           960
# 9               141               142            315  ...          1002
#
#    homes_num_10  med_val_17  med_val_16  med_val_15  med_val_14  med_val_13  \
# 0          5236       28000       27700       27400       26900       26700
# 1          2389       32500       32800       32800       37700       37800
# 2          5815       22700       22600       22400       24500       24400
# 3          3455       32300       32200       32200       32700       32700
# 4          5755       28100       27900       27700       32400       32400
# 5          1546       42300       42300       42400       44700       44850
# 6           335       19700       19700       19700       19000       19000
# 7          5715       58100       58200       58300       61600       61800
# 8           959       56250       56400       51900       41700       40750
# 9           995       49000       48600       48100       39300       39300
#
#    med_val_12  med_val_11  med_val_10
# 0       26500       40000       40400
# 1       37700       49300       49800
# 2       24300       49200       49500
# 3       32600       54300       54200
# 4       32100       51300       51600
# 5       44900       51300       51500
# 6       19000       28200       28200
# 7       61900       74800       74800
# 8       39900       39800       39900
# 9       39200       36850       36900
#
# [10 rows x 79 columns]

# %%
# Filter the DataFrame down only to those columns to chart
lb_parcels = df[['Neighborhood','land_bank_num_10','land_bank_num_13','land_bank_num_17']]

# Set the index to be 'Neighborhood'
lb_parcels = lb_parcels.set_index('Neighborhood')

lb_parcels.head(10)
# Out:
#                           land_bank_num_10  land_bank_num_13  land_bank_num_17
# Neighborhood
#  Broadway-Slavic Village               585              1052              1723
#  Collinwood-Nottingham                 392               615               844
#  Glenville                             963              1457              2006
#  Mount Pleasant                        278               478               867
#  Union-Miles                           650               923              1253
#  Brooklyn Centre                        45                53                83
#  Goodrich-Kirtland Pk                   54                60                73
#  Jefferson                              20                35                54
#  Ohio City                              85               102               104
#  Tremont                               108               119               142

# %%
# Create a bar chart of the data
lb_parcels.plot(kind="bar", figsize=(8,5))
# lb_parcels.set_xticklabels(lb_parcels['Neighborhood'], rotation=45)

plt.title('Land Bank Parcels')
plt.tight_layout()

plt.savefig('LandBankParcels.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
vacant = df[['Neighborhood','vacant_num_10','vacant_num_13','vacant_num_17']]

# Set the index to 'Neighborhood'
vacant = vacant.set_index('Neighborhood')

vacant.head(10)
# Out:
#                           vacant_num_10  vacant_num_13  vacant_num_17
# Neighborhood
#  Broadway-Slavic Village            905            832            654
#  Collinwood-Nottingham              320            290            250
#  Glenville                          897            760            686
#  Mount Pleasant                     240            300            275
#  Union-Miles                        498            422            362
#  Brooklyn Centre                    102            120            102
#  Goodrich-Kirtland Pk               123            126            110
#  Jefferson                          130            137            149
#  Ohio City                          338            330            291
#  Tremont                            497            480            315

# %%
# Create a bar chart of the data
vacant.plot(kind="bar", figsize=(8,5))

plt.title('Vacant Parcels')
plt.tight_layout()

plt.savefig('VacantParcels.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
forcl = df[['Neighborhood','forcl_10','forcl_13','forcl_17']]

# Set the index to 'Neighborhood'
forcl = forcl.set_index('Neighborhood')

forcl.head(10)
# Out:
#                           forcl_10  forcl_13  forcl_17
# Neighborhood
#  Broadway-Slavic Village       348       250       256
#  Collinwood-Nottingham         211       128       137
#  Glenville                     401       210       335
#  Mount Pleasant                241       134       219
#  Union-Miles                   345       140       163
#  Brooklyn Centre                67        70        50
#  Goodrich-Kirtland Pk            6         7        11
#  Jefferson                     229       165       109
#  Ohio City                      38        24        15
#  Tremont                        36        23        16

# %%
# Create a bar chart of the data
forcl.plot(kind="bar", figsize=(8,5))

plt.title('Foreclosures')
plt.tight_layout()

plt.savefig('Foreclosures.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
median_price = df[['Neighborhood','med_price_10','med_price_13','med_price_17']]

# Set the index to 'Neighborhood'
median_price = median_price.set_index('Neighborhood')

median_price.head(10)
# Out:
#                           med_price_10  med_price_13  med_price_17
# Neighborhood
#  Broadway-Slavic Village         11000         13350         19900
#  Collinwood-Nottingham           12000         15500         21100
#  Glenville                        6500         12000         16250
#  Mount Pleasant                   9000         15050         22100
#  Union-Miles                      9516         11000         19000
#  Brooklyn Centre                 20000         17750         26250
#  Goodrich-Kirtland Pk            26400         15850         28000
#  Jefferson                       36000         30750         56000
#  Ohio City                      128000         70500        123375
#  Tremont                         80000        130000        165000

# %%
# Create a bar chart of the data
median_price.plot(kind="bar", figsize=(8,5))

plt.title('Median Home Price')
plt.tight_layout()

plt.savefig('MedianPrice.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
median_value = df[['Neighborhood','med_val_10','med_val_13','med_val_17']]

# Set the index to 'Neighborhood'
median_value = median_value.set_index('Neighborhood')

median_value.head(10)
# Out:
#                           med_val_10  med_val_13  med_val_17
# Neighborhood
#  Broadway-Slavic Village       40400       26700       28000
#  Collinwood-Nottingham         49800       37800       32500
#  Glenville                     49500       24400       22700
#  Mount Pleasant                54200       32700       32300
#  Union-Miles                   51600       32400       28100
#  Brooklyn Centre               51500       44850       42300
#  Goodrich-Kirtland Pk          28200       19000       19700
#  Jefferson                     74800       61800       58100
#  Ohio City                     39900       40750       56250
#  Tremont                       36900       39300       49000

# %%
# Create a bar chart of the data
median_value.plot(kind="bar", figsize=(8,5))

plt.title('Median Home Value')
plt.tight_layout()

plt.savefig('MedianValue.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
