# %%
import pandas as pd
TestsFile='Grades3through11.csv'
TestsOrig=pd.read_csv(TestsFile)
#calculate neightborhood school improvement scores
#One for each grade/neighborhood
#Need English, Science, Math
TestsOrig["Neighborhood Average"]=TestsOrig.mean(axis=1)
TestsOrig.head()
#import main file, merging on neighborhood
# CuyahogaLandbankData-20190615.csv
#heatmap w/google based on those scores activity 3/10
# Out:
#                Neighborhood  Grade 6 Reading/English, 2016 (CMSD)  \
# 0          Bellaire-Puritas                                 20.69
# 1   Broadway-Slavic Village                                 11.59
# 2           Brooklyn Centre                                 12.50
# 3     Buckeye-Shaker Square                                  4.35
# 4          Buckeye-Woodhill                                 23.53
#
#    Grade 6 Math, 2016 (CMSD)  Grade 6 Reading/English, 2015 (CMSD)  \
# 0                      19.54                                 -99.0
# 1                       6.43                                 -99.0
# 2                      13.75                                 -99.0
# 3                       8.70                                 -99.0
# 4                       8.57                                 -99.0
#
#    Grade 6 Math, 2015 (CMSD)  Grade 6 Reading/English, 2014 (CMSD)  \
# 0                      31.71                                 66.67
# ...
