# %%
# Dependencies
from census import Census
from config import (census_key, gkey)
import gmaps
import numpy as np
import pandas as pd
import requests
import time

# from us import states
# c = Census(census_key, year=2013)

# %%
# print(gkey)

# %%
# base_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={address}1600+Amphitheatre+Parkway,+Mountain+View,+CA&key={gkey}"

testData = pd.read_csv("Data/testData2.csv")

testData.head()
# Out:
#      parcel                                         grantee  \
# 0    609012  CUYAHOGA COUNTY LAND REUTILIZATION CORPORATION
# 1   1728040                                  Morales Marvin
# 2  13507107  CUYAHOGA COUNTY LAND REUTILIZATION CORPORATION
# 3  13511076                            Wilson Eddie & Helen
# 4    610111  CUYAHOGA COUNTY LAND REUTILIZATION CORPORATION
#
#                   grantor                                    deeded_owner  \
# 0      PEREZ STACY A. JR.  CUYAHOGA COUNTY LAND REUTILIZATION CORPORATION
# 1        Serrano Miguel A                                  MORALES MARVIN
# 2  Thigpen Alfred & Hazel  CUYAHOGA COUNTY LAND REUTILIZATION CORPORATION
# 3                     NaN                            WILSON EDDIE & HELEN
# 4           Diaz Efigenia  CUYAHOGA COUNTY LAND REUTILIZATION CORPORATION
#
#    gross_certified_total                          par_addr_all  sales_amount  \
# 0                   5000  6600  COLGATE AVE CLEVELAND OH 44102             0
# ...

# %%
city = "Cleveland"
state = "OH"
addrNum = testData["Add num"]



# base_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={address}1600+Amphitheatre+Parkway,+Mountain+View,+CA&key={gkey}"

for address in addrNum:
    base_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={address},+{city}+{state}&key={gkey}"
