# %%
#Loading data, Pandas, etc.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
TestsFile="SchoolsData/Grades3through11clean.csv"
TestsOrig=pd.read_csv(TestsFile)

#Figuring out the average score for each neighborhood
TestsOrig["Neighborhood Average"]=TestsOrig.mean(axis=1)
TestsOrig.head()
# Out:
#                Neighborhood  Grade 6 Reading/English, 2016 (CMSD)  \
# 0          Bellaire-Puritas                                 20.69
# 1   Broadway-Slavic Village                                 11.59
# 2           Brooklyn Centre                                 12.50
# 3     Buckeye-Shaker Square                                  4.35
# 4          Buckeye-Woodhill                                 23.53
#
#    Grade 6 Math, 2016 (CMSD)  Grade 6 Reading/English, 2015 (CMSD)  \
# 0                      19.54                                   NaN
# 1                       6.43                                   NaN
# 2                      13.75                                   NaN
# 3                       8.70                                   NaN
# 4                       8.57                                   NaN
#
#    Grade 6 Math, 2015 (CMSD)  Grade 6 Reading/English, 2014 (CMSD)  \
# 0                      31.71                                 66.67
# ...

# %%
Grade3=TestsOrig[["Neighborhood", "3rd Grade English 2016","3rd Grade Math 2016","3rd Grade English 2015","3rd Grade Math 2015","3rd Grade English 2014","3rd Grade Math 2014","3rd Grade English 2013","3rd Grade Math 2013","3rd Grade English 2012","3rd Grade Math 2012","3rd Grade English 2011","3rd Grade Math 2011","3rd Grade English 2010", "3rd Grade Math 2010"]].copy()
Grade3["Neighborhood Average"]=Grade3.mean(axis=1)
Grade4=TestsOrig[["Neighborhood","Grade 4 Reading/English, 2016 (CMSD)","Grade 4 Math, 2016 (CMSD)","Grade 4 Reading/English, 2015 (CMSD)","Grade 4 Math, 2015 (CMSD)","Grade 4 Reading/English, 2014 (CMSD)","Grade 4 Math, 2014 (CMSD)","Grade 4 Reading/English, 2013 (CMSD)","Grade 4 Math, 2013 (CMSD)","Grade 4 Reading/English, 2012 (CMSD)","Grade 4 Math, 2012 (CMSD)","Grade 4 Reading/English, 2011 (CMSD)","Grade 4 Math, 2011 (CMSD)","Grade 4 Reading/English, 2010 (CMSD)","Grade 4 Math, 2010 (CMSD)"]].copy()
Grade4["Neighborhood Average"]=Grade4.mean(axis=1)
Grade4.head()
# Out:
#                Neighborhood  Grade 4 Reading/English, 2016 (CMSD)  \
# 0          Bellaire-Puritas                                 17.65
# 1   Broadway-Slavic Village                                  6.62
# 2           Brooklyn Centre                                 28.24
# 3     Buckeye-Shaker Square                                  7.14
# 4          Buckeye-Woodhill                                 13.16
#
#    Grade 4 Math, 2016 (CMSD)  Grade 4 Reading/English, 2015 (CMSD)  \
# 0                      44.05                                 58.49
# 1                      12.41                                 43.12
# 2                      47.06                                 41.18
# 3                       9.30                                 52.00
# 4                      15.38                                 57.14
#
#    Grade 4 Math, 2015 (CMSD)  Grade 4 Reading/English, 2014 (CMSD)  \
# 0                      40.00                                 76.62
# ...

# %%
#I manually split all the data by year, and this section loads all the data into seperate Pandas to find the mean score
#by neighborhood by year so we can tease out trends
Tendata='SchoolsData/2010Schoolsdata.csv'
Ten_df=pd.read_csv(Tendata)
Ten_df["2010 Neighborhood Average"]=Ten_df.mean(axis=1)
Elevendata="SchoolsData/2011Schools.csv"
Eleven_df=pd.read_csv(Elevendata)
Eleven_df["2011 Neighborhood Average"]=Eleven_df.mean(axis=1)
Twelvedata="SchoolsData/2012SchoolsData.csv"
Twelve_df=pd.read_csv(Twelvedata)
Twelve_df["2012 Neighborhood Average"]=Twelve_df.mean(axis=1)
Thirteendata="SchoolsData/2013SchoolsData.csv"
Thirteen_df=pd.read_csv(Thirteendata)
Thirteen_df["2013 Neighborhood Average"]=Thirteen_df.mean(axis=1)
Fourteendata="SchoolsData/2014ShcoolsData.csv"
Fourteen_df=pd.read_csv(Fourteendata)
Fourteen_df["2014 Neighborhood Average"]=Fourteen_df.mean(axis=1)
Fifteendata="SchoolsData/2015SchoolData.csv"
Fifteen_df=pd.read_csv(Fifteendata)
Fifteen_df["2015 Neighborhood Average"]=Fifteen_df.mean(axis=1)
Sixteendata="SchoolsData/2016SchoolData.csv"
Sixteen_df=pd.read_csv(Sixteendata)
Sixteen_df["2016 Neighborhood Average"]=Sixteen_df.mean(axis=1)
school_trend_df=TestsOrig[["Neighborhood"]]
school_trend_df["2010"]=Ten_df["2010 Neighborhood Average"]
school_trend_df["2011"]=Eleven_df["2011 Neighborhood Average"]
school_trend_df["2012"]=Twelve_df["2012 Neighborhood Average"]
school_trend_df["2013"]=Thirteen_df["2013 Neighborhood Average"]
school_trend_df["2014"]=Fourteen_df["2014 Neighborhood Average"]
school_trend_df["2015"]=Fifteen_df["2015 Neighborhood Average"]
school_trend_df["2016"]=Sixteen_df["2016 Neighborhood Average"]
school_trend_df = school_trend_df.set_index("Neighborhood")
print(school_trend_df)
# Out:
# /Users/NBLaptop/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/NBLaptop/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/NBLaptop/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#These are examples of the line graphs we will make
school_trend_df.to_csv("fileOne.csv", index=False, header=True)
years=["2010","2011","2012","2013","2014","2015","2016"]
neighborhood_one, = plt.plot(years, school_trend_df.loc['_Suburb',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="yellow")
neighborhood_two, = plt.plot(years, school_trend_df.loc[' Stockyards',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="green")
neighborhood_three, = plt.plot(years, school_trend_df.loc[' Goodrich-Kirtland Pk',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="orange") 
neighborhood_four, = plt.plot(years, school_trend_df.loc[' Edgewater',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="blue") 
neighborhood_five, = plt.plot(years, school_trend_df.loc[' Bellaire-Puritas',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="purple")
neighborhood_six, = plt.plot(years, school_trend_df.loc[' Broadway-Slavic Village',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="black")
neighborhood_seven, = plt.plot(years, school_trend_df.loc[' Brooklyn Centre',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="gray")
neighborhood_eight, = plt.plot(years, school_trend_df.loc[' Buckeye-Shaker Square',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="salmon")
neighborhood_nine, = plt.plot(years, school_trend_df.loc[' Buckeye-Woodhill',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="silver")
neighborhood_ten, = plt.plot(years, school_trend_df.loc[' Central',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="cyan")
neighborhood_eleven, = plt.plot(years, school_trend_df.loc[' Clark-Fulton',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="lightblue")
neighborhood_twelve, = plt.plot(years, school_trend_df.loc[' Collinwood-Nottingham',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="steelblue")
neighborhood_thirteen, = plt.plot(years, school_trend_df.loc[' Cudell',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="springgreen")
neighborhood_fourteen, = plt.plot(years, school_trend_df.loc[' Detroit Shoreway',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="aquamarine")
neighborhood_fifteen, = plt.plot(years, school_trend_df.loc[' Downtown',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="crimson")
neighborhood_sixteen, = plt.plot(years, school_trend_df.loc[' Euclid-Green',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="chartreuse")
neighborhood_seventeen, = plt.plot(years, school_trend_df.loc[' Fairfax',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="mediumblue")
neighborhood_eighteen, = plt.plot(years, school_trend_df.loc[' Glenville',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="blueviolet")
neighborhood_nineteen, = plt.plot(years, school_trend_df.loc[' Hough',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="mediumorchid")
neighborhood_twenty, = plt.plot(years, school_trend_df.loc[' Jefferson',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="dodgerblue")
neighborhood_twentyone, = plt.plot(years, school_trend_df.loc[' Kamm\'s',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="yellowgreen")
neighborhood_twentytwo, = plt.plot(years, school_trend_df.loc[' Kinsman',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="goldenrod")
neighborhood_twentythree, = plt.plot(years, school_trend_df.loc[' Lee-Harvard',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="olive")
neighborhood_twentyfour, = plt.plot(years, school_trend_df.loc[' Lee-Seville',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="azure")
neighborhood_twentyfive, = plt.plot(years, school_trend_df.loc[' Mount Pleasant',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="royalblue")
neighborhood_twentysix, = plt.plot(years, school_trend_df.loc[' North Shore Collinwood',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="lightseagreen")
neighborhood_twentyseven, = plt.plot(years, school_trend_df.loc[' Ohio City',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="lime")
neighborhood_twentyeight, = plt.plot(years, school_trend_df.loc[' Old Brooklyn',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="limegreen")
neighborhood_twentynine, = plt.plot(years, school_trend_df.loc[' St.Clair-Superior',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="magenta")
neighborhood_thirty, = plt.plot(years, school_trend_df.loc[' Tremont',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="deeppink")
neighborhood_thirtyone, = plt.plot(years, school_trend_df.loc[' Union-Miles',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="brown")
neighborhood_thirtytwo, = plt.plot(years, school_trend_df.loc[' West Boulevard',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="tomato")
neighborhood_thirtythree, = plt.plot(years, school_trend_df.loc[' _Unknown neighborhood',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="khaki")
plt.show()

# %%
#a graoh that shows the ten enighborhoods we picked, plus the 'burbs for comparison.
#high-land bank involvement is red, low land bank involvement is green'
neighborhood_thirty, = plt.plot(years, school_trend_df.loc[' Tremont',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="green")
neighborhood_three, = plt.plot(years, school_trend_df.loc[' Goodrich-Kirtland Pk',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="darkgreen") 
neighborhood_twenty, = plt.plot(years, school_trend_df.loc[' Jefferson',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="lime")
neighborhood_twentyseven, = plt.plot(years, school_trend_df.loc[' Ohio City',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="seagreen")
neighborhood_seven, = plt.plot(years, school_trend_df.loc[' Brooklyn Centre',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="limegreen")

neighborhood_six, = plt.plot(years, school_trend_df.loc[' Broadway-Slavic Village',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="red")
neighborhood_twelve, = plt.plot(years, school_trend_df.loc[' Collinwood-Nottingham',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="tomato")
neighborhood_twentyfive, = plt.plot(years, school_trend_df.loc[' Mount Pleasant',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="orangered")
neighborhood_thirtyone, = plt.plot(years, school_trend_df.loc[' Union-Miles',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="r")
neighborhood_eighteen, = plt.plot(years, school_trend_df.loc[' Glenville',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="crimson")
neighborhood_one, = plt.plot(years, school_trend_df.loc['_Suburb',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="black")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
       ncol=2, mode="expand", borderaxespad=0.)

plt.show()

#a couple of other neighbrhoods that interested me for various reasons
neighborhood_ten, = plt.plot(years, school_trend_df.loc[' Central',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="cyan")
neighborhood_four, = plt.plot(years, school_trend_df.loc[' Edgewater',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="blue") 
neighborhood_fourteen, = plt.plot(years, school_trend_df.loc[' Detroit Shoreway',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="aquamarine")
neighborhood_twentyone, = plt.plot(years, school_trend_df.loc[' Kamm\'s',["2010","2011","2012","2013","2014", "2015","2016"]], 
                             color="yellowgreen")
plt.show()
